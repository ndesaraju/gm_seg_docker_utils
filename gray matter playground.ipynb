# %%
import handl_gm_seg_flyhweel as hand
from glob import glob
import nibabel as nb
import os

# %%
ms_list=glob('/data/henry6/esha/Data/Interp_10/Current_Data/all/ms*control.nii.gz')
cut=input(ms_list)
ms_list=ms_list[int(cut):]
for x in ms_list:
    print(x)
    hand.gray_matter_seg_no_preproc(x,'/data/henry4/jjuwono/outputs_{}'.format(os.path.basename(x).split('.')[0]),'')
# Out:
# ['/data/henry6/esha/Data/Interp_10/Current_Data/all/ms10_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms11_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms12_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms13_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms14_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms15_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms16_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms17_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms18_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms19_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms20_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms2_cord_control.nii.gz', '/data/henry6/esha/Data/Interp_10/Current_Data/all/ms1_cord_co
# ...
